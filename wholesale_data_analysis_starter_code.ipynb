# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd # type: ignore

df = pd.read_csv('Resources/client_dataset.csv')
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
print(f"Unique categories: {df['category'].nunique()}")
df['category'].unique()
# Out:
# Unique categories: 5
# array(['decor', 'consumables', 'software', 'furniture', 'electronics'],
#       dtype=object)

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
print(f"Unique jobs: {df['job'].nunique()}")
df['job'].unique()
# Out:
# Unique jobs: 498
# array(['Immunologist', 'Music therapist', 'Accounting technician',
#        'Chiropractor', 'Production designer, theatre/television/film',
#        'Barista', 'Theme park manager', 'Chiropodist',
#        'Secretary, company', 'Engineer, broadcasting (operations)',
#        'Surveyor, land/geomatics', 'Lobbyist', 'Psychologist, clinical',
#        'Research scientist (maths)', 'Government social research officer',
#        'Colour technologist', 'Production assistant, television',
#        'Lecturer, further education', 'Commercial art gallery manager',
#        'Architectural technologist', 'Engineer, manufacturing systems',
#        'Textile designer', 'Air cabin crew', 'Medical illustrator',
#        'Technical brewer', 'Radiographer, therapeutic',
#        'Race relations officer', 'Horticulturist, amenity',
#        'Surveyor, rural practice', 'Science writer', 'Airline pilot',
#        'Environmental health practitioner', 'Warehouse manager',
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
research_data = pd.DataFrame(df.columns)


research_data.set_index(research_data[0], inplace=True)
total_entries = len(df.index)
research_data['count'] = pd.Series(df.count())
research_data['nulls'] = total_entries - research_data['count']
research_data['type'] = pd.Series(df.dtypes)
del research_data[0]

research_data.index.name = None
research_data
# Out:
#              count  nulls     type
# first        54639      0   object
# last         54639      0   object
# job          54639      0   object
# phone        54639      0   object
# email        54639      0   object
# client_id    54639      0    int64
# order_id     54639      0    int64
# order_date   54639      0   object
# order_week   54639      0    int64
# order_year   54639      0    int64
# item_id      54639      0   object
# category     54639      0   object
# subcategory  54639      0   object
# unit_price   54639      0  float64
# unit_cost    54639      0  float64
# unit_weight  54639      0  float64
# qty          54639      0    int64
# line_number  54639      0    int64

# %%
# What three item categories had the most entries?
df['category'].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# decor           7954
# electronics     2832
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

most_entries_cat = df['category'].value_counts().index.tolist()[0]
df.loc[df['category'] == most_entries_cat]['subcategory'].value_counts().head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
df['client_id'].value_counts().head()
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
top_client_ids = df['client_id'].value_counts().index.tolist()[:5]
top_client_ids
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
top_client = top_client_ids[0]
top_client_total_units = df.loc[df['client_id'] == top_client]['qty'].sum()
top_client_total_units
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df["line_subtotal"] = df["unit_price"] * df["qty"]
df[['unit_price', 'qty', 'line_subtotal']].head(2)
# Out:
#    unit_price  qty  line_subtotal
# 0     1096.80  105      115164.00
# 1       24.95   21         523.95

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.

df['total_weight'] = df['unit_weight'] * df['qty']

def calculate_shipping_price(row):
    ship_per_pound_price = 0
    if row['total_weight'] > 50:
        ship_per_pound_price = 7
    else:
        ship_per_pound_price = 10

    return  ship_per_pound_price * row['total_weight']

df['shipping_price'] = df.apply(calculate_shipping_price, axis=1)
df[['unit_price', 'unit_weight', 'qty', 'total_weight', 'shipping_price']]
# Out:
#    unit_price  unit_weight  qty  total_weight  shipping_price
# 0     1096.80         7.50  105        787.50         5512.50
# 1       24.95         1.49   21         31.29          312.90
# 2       13.52         1.68   39         65.52          458.64

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%
def calculate_total(row):
    tax_perc = 9.25 / 100
    total = row['line_subtotal'] + row['shipping_price']
    return total * tax_perc
df['line_price'] = df.apply(calculate_total, axis=1)
df[['line_subtotal', 'shipping_price', 'line_price']].head(3)
# Out:
#    line_subtotal  shipping_price    line_price
# 0      115164.00         5512.50  11162.576250
# 1         523.95          312.90     77.408625
# 2         527.28          458.64     91.197600

# %%
def calculate_total(row):
    tax_perc = 9.25 / 100
    total = row['line_subtotal'] + row['shipping_price']
    total *= (1 + tax_perc)
    return total
df['line_price'] = df.apply(calculate_total, axis=1).round(2)
df[['line_subtotal', 'shipping_price', 'line_price']].head(3)
# Out:
#    line_subtotal  shipping_price  line_price
# 0      115164.00         5512.50   131839.08
# 1         523.95          312.90      914.26
# 2         527.28          458.64     1077.12

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
df['line_cost'] = (df['unit_cost'] + df['qty'] + df['shipping_price']).round(2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %%
# Create a column for the profit of each line using line cost and line price
df['line_profit'] = df['line_price'] - df['line_cost']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_cost unit_weight  qty  line_number  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
# Expected:
# Order 2742071 total: $152811.89
# Order 2173913 total: $162388.71
# Order 6128929 total: $923441.25

order_ids = [2742071, 2173913, 6128929]
expected_total = [152811.89, 162388.71, 923441.25]
confirmation_orders = df[df['order_id'].isin(order_ids)]
confirmation_orders.groupby('order_id')[['line_price']].sum()
# Out:
#           line_price
# order_id
# 2173913    162388.71
# 2742071    152811.89
# 6128929    923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.
# 33615: $8377308.52
# 66037: $10259514.79
# 46820: $9743794.36
# 38378: $12906550.87
# 24741: $82268892.02

top_clients = df[df['client_id'].isin(top_client_ids)]
top_clients.groupby('client_id')[['line_price']].sum()
# Out:
#             line_price
# client_id
# 24741      82268892.02
# 33615       8377308.52
# 38378      12906550.87
# 46820       9743794.36
# 66037      10259514.79

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit.
# Out:
#    client_id     qty  shipping_price   line_price    line_cost  line_profit
# 0      33615   64313      1828984.89   8377308.52   6175313.91   2201994.61
# 1      66037   43018      1395151.85  10259514.79   7004482.98   3255031.81
# 2      46820   75768      1601448.84   9743794.36   7007191.64   2736602.72
# 3      38378   73667      3429455.40  12906550.87   9634720.98   3271829.89
# 4      24741  239862      5126448.37  82268892.02  45688899.71  36579992.31

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 


# Rename the columns to reflect the change in the money format.
# Out:
#    Client ID   Units  Shipping (millions)  Total Revenue (millions)  \
# 0      33615   64313             1.828985                  8.377309
# 1      66037   43018             1.395152                 10.259515
# 2      46820   75768             1.601449                  9.743794
# 3      38378   73667             3.429455                 12.906551
# 4      24741  239862             5.126448                 82.268892
#
#    Total Cost (millions)  Total Profit (millions)
# 0               6.175314                 2.201995
# 1               7.004483                 3.255032
# 2               7.007192                 2.736603
# 3               9.634721                 3.271830
# 4              45.688900                36.579992

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
# Out:
#    Client ID   Units  Shipping (millions)  Total Revenue (millions)  \
# 4      24741  239862             5.126448                 82.268892
# 3      38378   73667             3.429455                 12.906551
# 1      66037   43018             1.395152                 10.259515
# 2      46820   75768             1.601449                  9.743794
# 0      33615   64313             1.828985                  8.377309
#
#    Total Cost (millions)  Total Profit (millions)
# 4              45.688900                36.579992
# 3               9.634721                 3.271830
# 1               7.004483                 3.255032
# 2               7.007192                 2.736603
# 0               6.175314                 2.201995
